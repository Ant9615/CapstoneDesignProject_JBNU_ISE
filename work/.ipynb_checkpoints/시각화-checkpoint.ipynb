# %% [markdown]
# 카카오 api -> 한옥마을 음식점, 한옥마을 카페 등 키워드 검색 -> 위치 가져옴 -> 시각화

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ar = pd.read_csv('./address.csv', encoding='utf-8')

# %%
ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   89 non-null     int64
#  1   식당명          89 non-null     object
#  2   도로명주소        89 non-null     object
#  3   지번주소         89 non-null     object
#  4   식당위도         89 non-null     float64
#  5   식당경도         89 non-null     float64
#  6   Unnamed: 5   0 non-null      float64
#  7   Unnamed: 6   0 non-null      float64
#  8   Unnamed: 7   0 non-null      float64
#  9   Unnamed: 8   0 non-null      float64
#  10  Unnamed: 9   0 non-null      float64
#  11  Unnamed: 10  0 non-null      float64
#  12  Unnamed: 11  0 non-null      float64
#  13  Unnamed: 12  0 non-null      float64
#  14  Unnamed: 13  0 non-null      float64
#  15  Unnamed: 14  0 non-null      float64
#  16  Unnamed: 15  0 non-null      float64
#  17  Unnamed: 16  0 non-null      float64
# ...

# %%
import folium as g
import json

# %%
gg_map = g.Map(location=[35.81563488182217, 127.15352107073629], zoom_start=17)

for i in range(len(ar)):
    tit = ar.loc[i]['식당명']
    marker1=g.Marker([ar.loc[i]['식당위도'], ar.loc[i]['식당경도']], tooltip=tit,
                    icon = g.Icon(color='red'))
    marker1.add_to(gg_map)
gg_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
ar.to_excel('./ar.xlsx')

# %%
gg_map.save('./viss.html')

# %% [markdown]
# 위의 데이터로 부족함 데이터크롤링 필요함

# %%
res_2 = pd.read_excel('./res_4.xlsx')
res_2.head()
# Out:
#    Unnamed: 0             name                          address   Latitude  \
# 0         0.0           양반가한정식       전라북도 전주시 완산구 최명희길 30-2 양반가  35.816128
# 1         1.0            다우랑만두              전라북도 전주시 완산구 태조로 33  35.814189
# 2         2.0           한국집비빔밥             전라북도 전주시 완산구 어진길 119  35.816394
# 3         3.0      메르밀진미집 본점국수  전라북도 전주시 완산구 전주천동로 94 메르밀진미집 본점  35.811185
# 4         4.0  45년전통비빔밥종로회관비빔밥            전라북도 전주시 완산구 전동성당길 98  35.814846
#
#     Longitude Category
# 0  127.151237      음식점
# 1  127.151038      음식점
# 2  127.148275      음식점
# 3  127.150471      음식점
# 4  127.148775      음식점

# %%
res_2.columns
# Out:
# Index(['Unnamed: 0', 'name', 'address', 'Latitude', 'Longitude', 'Category'], dtype='object')

# %%
g_map = g.Map(location=[35.81563488182217, 127.15352107073629], zoom_start=17)


for i in range(len(res_2)):
    lat = res_2.loc[i, 'Latitude']
    long = res_2.loc[i, 'Longitude']
    color = 'red'
    tit = res_2.loc[i, 'name']
    
    if res_2.loc[i, 'Category'] == '카페':
        color = 'blue'    
    elif res_2.loc[i, 'Category'] == '숙소': 
        color = 'green'
    elif res_2.loc[i, 'Category'] == '유적지':
        color = 'white'
    elif res_2.loc[i, 'Category'] == '후보지':
        color = 'black'
        
    g.CircleMarker([lat,long], color=color,tooltip=tit, radius = 4).add_to(g_map)

g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
g_map.save('./vis.html')
