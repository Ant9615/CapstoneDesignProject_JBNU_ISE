# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
address = pd.read_csv('./address.csv')
address.columns
items = address.loc[:,'식당명']
items = items.tolist()

# %%
driver = webdriver.Chrome("./chromedriver")

count = 0
items = address.loc[:,'식당명']
items = items.tolist()
rating_df = pd.DataFrame()
for item in items:
    # 리뷰가 없을 때의 코드
    
    driver.get("https://map.kakao.com/") # 카카오 지도 접속하기
    searchbox = driver.find_element_by_xpath("//input[@id='search.keyword.query']") # 검색창에 입력하기
    searchbox.send_keys(item)
    searchbutton = driver.find_element_by_xpath("//button[@id='search.keyword.submit']") # 검색버튼 누르기
    driver.execute_script("arguments[0].click();", searchbutton)
    time.sleep(2)
    
    if len(driver.find_elements_by_xpath("//a[@class='moreview']")) != 0:
        print('식당 존재')
        driver.execute_script('window.open("about:blank", "_blank");') # 새 탭 열기
        reviewbutton = driver.find_element_by_xpath("//a[@class='numberofscore']")
        content_url = reviewbutton.get_attribute("href")    
        tabs = driver.window_handles
        driver.switch_to_window(tabs[1]) # 새 탭으로 이동
        driver.get(content_url) # 링크 열기
        time.sleep(3)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        review_lists = soup.select('.list_evaluation > li')
        print(len(review_lists))
        if len(review_lists) != 0 :
            for i, review in enumerate(review_lists) :
                user_review = review.select('.txt_comment > span') # 리뷰
                rating = review.select('.grade_star > em') # 별점
                img_url = review.select('.link_photo > img ') #이미지url
                user_id = review.select('.append_item > a[data-userid]') # user 정보 html 파싱
                timestamp = review.select(' div > span.time_write') #시간정보
                print(user_review)
                print(rating)
                print(img_url)
                print(user_id)
                print(timestamp)
                row = {"UserID":user_id[0].get('data-userid'),"ItemID":item,"Rating":rating,"Timestamp":timestamp}
                row = pd.DataFrame(row, index=[i])
                rating_df = rating_df.append(row,ignore_index=True)
                time.sleep(1)
        else :
            print("리뷰가 없습니다")
            
        try:
            for i in range(2,999):
                time.sleep(2)
                another_review = driver.find_element_by_xpath("//a[@data-page='" + str(i) + "']")
                another_review.click()
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                review_lists = soup.select('.list_evaluation > li')
                if len(review_lists) != 0 :
                    for i, review in enumerate(review_lists) :
                        user_review = review.select('.txt_comment > span') # 리뷰
                        rating = review.select('.grade_star > em') # 별점
                        img_url = review.select('.link_photo > img ') #이미지url
                        user_id = review.select('.append_item > a[data-userid]') # user 정보 html 파싱
                        timestamp = review.select(' div > span.time_write') #시간정보
                        row = {"UserID":user_id[0].get('data-userid'),"ItemID":item,"Rating":rating,"Timestamp":timestamp}
                        row = pd.DataFrame(row, index=[i])
                        rating_df = rating_df.append(row,ignore_index=True)
                        time.sleep(1)
        except:
            print("더 이상 리뷰 존재 X")
        driver.switch_to_window(tabs[0])
        print("기본 페이지로 돌아가자")
            
    else:
        print("식당 존재 x")
# Out:
# 식당 존재
# <ipython-input-69-42dc37cb8c9e>:23: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(tabs[1]) # 새 탭으로 이동
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# <ipython-input-69-42dc37cb8c9e>:70: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(tabs[0])
# 식당 존재
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 5
# [<span>쫀득하고 맛있습니다. 막국수도 정말 맛있어요. 콩나물국이 대단합니다. 더 번창하십쇼! </span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wkE8WImdR0/S9TmFjc4xzIfr3jhaIDh90/3922jc.jpg" data-platform="kakaomap" data-userid="fomd99" data-username="먹보의길" href="javascript:void(0);">먹보의길</a>]
# [<span class="time_write">2021.01.16.</span>]
# [<span>괜찮아요</span>]
# [<em class="num_rate">3<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/040fc19c68251225bac3df456976b7f18147ce7d?original" data-platform="kakaomap" data-userid="qk8du6" data-username="jinyung" href="javascript:void(0);">jinyung</a>]
# [<span class="time_write">2020.10.11.</span>]
# [<span>완전 맛집.. ㅁ1친nom임.. 쫀쫀한 족발... 공기밥에 시래기?우거지?국 말아먹으면 대환장... 근데 솔직히 막국수는 노맛..ㅋ 둘째넷째 화요일 쉬니까 꼭 참고하세요..ㅠ</span>]
# [<em class="num_rate">4<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//t1.kakaocdn.net/thumb/C80x80.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2Fa10e58e4cd7ec98c756cf1c61bcbd3ae2ed3f06c%3Foriginal" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/b00f5868f50febf0da0451fada0622cc48434692?original" data-platform="kakaomap" data-userid="18li8p1" data-username="ㄱㅅㅇ" href="javascript:void(0);">ㄱㅅㅇ</a>]
# [<span class="time_write">2020.07.14.</span>]
# [<span>맛남~</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/295fa805232ab04d5869d1f09bbbf57525583282?original" data-platform="kakaomap" data-userid="b2k9uv" data-username="drive4801" href="javascript:void(0);">drive4801</a>]
# [<span class="time_write">2019.10.03.</span>]
# [<span>보통이에요</span>]
# [<em class="num_rate">3<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wkjxaHNl1J/bKjf2jIzjnsG0a4eVBhjh0/pr5myy.jpg" data-platform="kakaomap" data-userid="vmigjq" data-username="황기택" href="javascript:void(0);">황기택</a>]
# [<span class="time_write">2019.05.13.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 0
# 리뷰가 없습니다
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 2
# [<span>가성비 좋고 음식이 맛있어요.  재방문 의사 있음. </span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//t1.kakaocdn.net/thumb/C80x80.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2F6434a3ec34fbc891da7c20fef4e52abc3de9f7f0%3Foriginal" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="https://p.kakaocdn.net/th/talkp/wmb3Mmf3OR/RWkEo2ijvdtzMAlrQsbjwK/t88qba_640x640_s.jpg" data-platform="kakaomap" data-userid="18od714" data-username="yuri" href="javascript:void(0);">yuri</a>]
# [<span class="time_write">2020.11.14.</span>]
# [<span>맛있어요! 한옥마을 둘러보다가 너무 더워서 보이는 집 찾아간거였는데 맛있었어요. 사장님 부부도 정말 친절하시고 가게도 청결해보였어요. 다만 한옥마을 내부 가게들로만 사람들이 몰려 손님이 별로 없었는데 앞으로는 더 장사 잘 되셨으면 좋겠어요~~</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//t1.kakaocdn.net/thumb/C80x80.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2Fda8554f356a61e412f66b090365789ef81e42465%3Foriginal" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/8ccb498790287650acf80eff58d25e0a609dc4fe?original" data-platform="kakaomap" data-userid="11megu7" data-username="봄이" href="javascript:void(0);">봄이</a>]
# [<span class="time_write">2019.07.23.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 5
# [<span>고기며 반찬이며 하나하나 정성이 들어간 게 느껴져요. 추천합니다~</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="" data-platform="kakaomap" data-userid="1gigm4j" data-username="손희성" href="javascript:void(0);">손희성</a>]
# [<span class="time_write">2021.02.15.</span>]
# [<span>고기도 엄청 좋고 맛잇고 반찬이랑 밥종류들을 다 직접 해주시는데. 정말 정말 맛있어요!!!  </span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://k.kakaocdn.net/dn/cWU4Va/btqzkKi0ooP/WK8ivm14kCDa2UNdmCcmK1/img_640x640.jpg" data-platform="kakaomap" data-userid="14k6i9u" data-username="홍민혜(🌟)" href="javascript:void(0);">홍민혜(🌟)</a>]
# [<span class="time_write">2020.11.25.</span>]
# [<span>#숙성삼겹살#삼미당#한옥마을맛집#객사근교맛집#JMTGR#전주맛집#삼겹살맛집#분위기#인생맛집#전주토박이추천맛집#데이트맛집 제가 가본 고깃집중에 정말 최고에요 굿굿 밑반찬도 직접 하셔서 정말 맛있고 상추랑 깻잎 고추도 직접 재배하셔서 신선하고 좋아요 분위기도 정말 좋아서 연인끼리 데이트하기도 정말 좋아요 사장님도 엄청 친절하고 특히 시국이 시국인지라 코로나걱정...</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="" data-platform="kakaomap" data-userid="1bhshlg" data-username="한태성" href="javascript:void(0);">한태성</a>]
# [<span class="time_write">2020.08.27.</span>]
# [<span>고기가 진짜 맛있고 반찬이랑 사장님의 스페셜 메뉴까지 진짜 잘먹고 갑니다~~~</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wlNjScSxgd/7zyzPp8LdTxCs37KmCCFWK/8ys5jp_640x640_s.jpg" data-platform="kakaomap" data-userid="19csmk3" data-username="samuellee" href="javascript:void(0);">samuellee</a>]
# [<span class="time_write">2020.07.24.</span>]
# [<span>아니 존맛탱</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/e0084315b3abfe3079c44ea6343791cc5a425562?original" data-platform="kakaomap" data-userid="g7ofub" data-username="이것이 이것이다" href="javascript:void(0);">이것이 이것이다</a>]
# [<span class="time_write">2020.01.16.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 5
# [<span>떡갈비 정식 시켰는데 맛있었습니다 두부랑 파전 너무맛있었어요 사장님도 친절하시고 잘 먹고갑니다!</span>]
# [<em class="num_rate">4<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/5830c1e83142a66a74226baddad5468457a5bc2d?original" data-platform="kakaomap" data-userid="se7m3q" data-username="수정" href="javascript:void(0);">수정</a>]
# [<span class="time_write">2020.08.01.</span>]
# [<span>떡갈비 정식 먹었습니다. 두부! 특히 맛이 있고, 15찬 정도 나옵니다.</span>]
# [<em class="num_rate">4<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//t1.kakaocdn.net/thumb/C80x80.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2Fc61cf560c1f6c8b15e08112058d117ea4359099a%3Foriginal" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/9a946d4f5c6ba2dd79427b0e0c0187f67cb412b2?original" data-platform="kakaomap" data-userid="nmnf8q" data-username="EH" href="javascript:void(0);">EH</a>]
# [<span class="time_write">2020.06.22.</span>]
# [<span>현지인들 맛집이라고 추천받고 갔습니다. 떡갈비정식(14000원) 이고 정말 맛있었어요^^ 특히 두부가 맛있었구요 떡갈비도 맛깔났네요~ 추천합니다</span>]
# [<em class="num_rate">4<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://t1.daumcdn.net/local/kakaomapPhoto/profile/4429e820a2d78b348832df6a252e6a9f57792f8d?original" data-platform="kakaomap" data-userid="105r3n6" data-username="쭈" href="javascript:void(0);">쭈</a>]
# [<span class="time_write">2020.02.08.</span>]
# [<span>음식이 맛있습니다. 깔끔합니다. 조용합니다! 왕추천</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wk0yVWftnd/u2SAvFXWBMKZUBbUqTCjAK/c29zr0.jpg" data-platform="kakaomap" data-userid="tkoske" data-username="이우진" href="javascript:void(0);">이우진</a>]
# [<span class="time_write">2020.01.02.</span>]
# [<span>매당 정식 먹었어요 깔끔한 상차림에 직접 만든 두부라서 그런지 너무 맛있어요</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# [<img alt="포토뷰어" class="img_profile" height="78" src="//t1.kakaocdn.net/thumb/C80x80.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocal%2FkakaomapPhoto%2Freview%2Fd59847d7edecd6218001b92389b41b4c27daf04c%3Foriginal" width="78"/>]
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wkJetIY7RN/bP7qVZKwyow3rLzL9hsOj0/v4dxkx.jpg" data-platform="kakaomap" data-userid="mp0ca7" data-username="백 경록" href="javascript:void(0);">백 경록</a>]
# [<span class="time_write">2019.07.09.</span>]
# 더 이상 리뷰 존재 X
# 기본 페이지로 돌아가자
# 식당 존재
# 4
# [<span>Good :)</span>]
# [<em class="num_rate">5<span class="screen_out">점</span></em>]
# []
# [<a class="link_user" data-ismy="false" data-ori="http://th-p.talk.kakao.co.kr/th/talkp/wk1TPNM1nz/T3b6V794bW0kdWaN4CJ2zk/neqqad.jpg" data-platform="kakaomap" data-userid="bg9k3u" data-username="정다은" href="javascript:void(0);">정다은</a>]
# [<span class="time_write">2019.01.30.</span>]
# [<span>남자화장실 칸이 한칸이라 너무 곤욕이었습니다 </span>]
# [<em class="num_rate">2<span class="screen_out">점</span></em>]
# []
# []
# [<span class="time_write">2017.10.05.</span>]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-69-42dc37cb8c9e> in <module>
#      40                 print(user_id)
#      41                 print(timestamp)
# ---> 42                 row = {"UserID":user_id[0].get('data-userid'),"ItemID":item,"Rating":rating,"Timestamp":timestamp}
#      43                 row = pd.DataFrame(row, index=[i])
#      44                 rating_df = rating_df.append(row,ignore_index=True)
#
# IndexError: list index out of range

# %%
import string 
f = pd.read_csv('./전라북도 전주시_음식점 정보_20201229.csv',encoding = 'utf-8')
# f.head()
f_pung = f.loc[f['지번주소'].str.contains('풍남동')]
# print(f_pung)
f_kyo = f.loc[f['지번주소'].str.contains('교동')]
f_j = [f_pung,f_kyo]
f_hanok = pd.concat([f_pung,f_kyo])
f_hanok.drop(f_hanok.iloc[:,5:], axis=1)
f_hanok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95 entries, 1648 to 2368
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   식당명          95 non-null     object
#  1   도로명주소        95 non-null     object
#  2   지번주소         95 non-null     object
#  3   식당위도         95 non-null     float64
#  4   식당경도         95 non-null     float64
#  5   Unnamed: 5   0 non-null      float64
#  6   Unnamed: 6   0 non-null      float64
#  7   Unnamed: 7   0 non-null      float64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  0 non-null      float64
#  12  Unnamed: 12  0 non-null      float64
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  Unnamed: 17  0 non-null      float64
#  18  Unnamed: 18  0 non-null      float64
#  19  Unnamed: 19  0 non-null      float64
#  20  Unnamed: 20  0 non-null      float64
#  21  Unnamed: 21  0 non-null      float64
#  22  Unnamed: 22  0 non-null      float64
#  23  Unnamed: 23  0 non-null      float64
#  24  Unnamed: 24  0 non-null      float64
#  25  Unnamed: 25  0 non-null      float64
#  26  Unnamed: 26  0 non-null      float64
#  27  Unnamed: 27  0 non-null      float64
# dtypes: float64(25), object(3)
# memory usage: 21.5+ KB

# %%
# f_duc = f_hanok.loc[f_hanok['도로명주소'].str.contains('덕진구')]
f_hanok=f_hanok[~f_hanok.도로명주소.str.contains('덕진구')]
f_hanok.info()
f_hanok.to_csv('./address.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89 entries, 1666 to 2368
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   식당명          89 non-null     object
#  1   도로명주소        89 non-null     object
#  2   지번주소         89 non-null     object
#  3   식당위도         89 non-null     float64
#  4   식당경도         89 non-null     float64
#  5   Unnamed: 5   0 non-null      float64
#  6   Unnamed: 6   0 non-null      float64
#  7   Unnamed: 7   0 non-null      float64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  0 non-null      float64
#  12  Unnamed: 12  0 non-null      float64
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  Unnamed: 17  0 non-null      float64
#  18  Unnamed: 18  0 non-null      float64
#  19  Unnamed: 19  0 non-null      float64
#  20  Unnamed: 20  0 non-null      float64
#  21  Unnamed: 21  0 non-null      float64
#  22  Unnamed: 22  0 non-null      float64
#  23  Unnamed: 23  0 non-null      float64
#  24  Unnamed: 24  0 non-null      float64
#  25  Unnamed: 25  0 non-null      float64
#  26  Unnamed: 26  0 non-null      float64
#  27  Unnamed: 27  0 non-null      float64
# dtypes: float64(25), object(3)
# memory usage: 20.2+ KB

# %%
import os
path = os.getcwd()
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'address.csv',
#  'chromedriver.exe',
#  'graduate_analy.ipynb',
#  '전라북도 전주시_음식점 정보_20201229.csv',
#  '종설 크롤링.ipynb']
